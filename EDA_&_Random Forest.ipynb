# %% [markdown]
# #### Importing Libraries

# %%
# import basic libraries
import numpy as np
import pandas as pd
from time import time
from IPython.display import display 
# import plot libraries
import seaborn as sns
sns.set_palette('Set2')
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Data file loading with column header

# %%
df1 = pd.read_csv('census-income.data',names=["age","workclass","fnlwgt","education","education-num","marital-status","occupation","relationship","race","sex","capital-gain","capital-loss","hours-per-week","native-country", "income"])

# %% [markdown]
# #### Exploratory data Analysis

# %%
df1.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
print(df1.shape)
# Out:
# (32561, 15)

# %%
df1.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# income            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df1.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df1.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
df1.nunique()
# Out:
# age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education-num        16
# marital-status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital-gain        119
# capital-loss         92
# hours-per-week       94
# native-country       42
# income                2
# dtype: int64

# %% [markdown]
# ##### Checking Target Variables

# %%
df1.income.nunique()
# Out:
# 2

# %%
print(df1.income.value_counts())
# Out:
#  <=50K    24720
#  >50K      7841
# Name: income, dtype: int64

# %% [markdown]
# #### Plotting and Visualization to find out correlation of numerical variables if any

# %%
plt.figure(figsize=(20,10))
c= df1.corr()
sns.heatmap(c,cmap='BrBG',annot=True)
c
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education-num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital-gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital-loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours-per-week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 hours-per-week
# age                   0.068756
# fnlwgt               -0.018768
# education-num         0.148123
# capital-gain          0.078409
# capital-loss          0.054256
# hours-per-week        1.000000

# %% [markdown]
# #### This scatter plot will give us a picture of bivariate relationship between the variables
# ###### we can see whether there are any regression line can be drawn

# %%
pd.plotting.scatter_matrix(df1, figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B23B9187F0>,
# ...
#       dtype=object)

# %%
sns.heatmap(df1.corr(),vmax=.3, square=True, annot=True)

# %% [markdown]
# #### Age variable distribution pattern

# %%
plt.subplot(2, 1, 1)
df1['age'].hist()
plt.title('age distribution', size = 20)
plt.xlabel('age', size = 15)
plt.ylabel('Frequency', size = 15)
plt.vlines(x = np.mean(df1['age']), ymin = 0, ymax = 7000, color = 'r')
plt.xticks(size = 12)
plt.yticks(size = 12)

plt.subplot(2, 1, 2)
df1['hours-per-week'].hist()
plt.title('hours-per-week distribution', size = 20)
plt.xlabel('hours per week', size = 15)
plt.ylabel('Frequency', size = 15)
plt.vlines(x = np.mean(df1['age']), ymin = 0, ymax = 7000, color = 'r')
plt.xticks(size = 12)
plt.yticks(size = 12)
# Out:
# (array([    0.,  5000., 10000., 15000., 20000.]),
#  <a list of 5 Text yticklabel objects>)

# %% [markdown]
# #### Categorical variable summary

# %%
df1.describe(include =['O'])
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      32561     32561               32561           32561        32561
# unique         9        16                   7              15            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22696     10501               14976            4140        13193
#
#          race    sex native-country income
# count   32561  32561          32561  32561
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    27816  21790          29171  24720

# %%
labels = df1.education.unique()
sizes = [df1['education'].value_counts()]
# pie plot for categorical column
fig1, ax1 = plt.subplots()
ax1.pie(sizes,labels=labels, autopct= '%1.1f%%', shadow=True)
ax1.axis('equal')
# Out:
# (-1.1271732668917098,
#  1.1012939650900815,
#  -1.1016736936782394,
#  1.1077885674913182)

# %%
df1.workclass.nunique()
# Out:
# 9

# %%
df1.workclass.value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
labels2 = df1.workclass.unique()
sizes2 = [df1['workclass'].value_counts()]
# pie plot for categorical column
fig2, ax2 = plt.subplots()
ax2.pie(sizes2,labels=labels2, autopct= '%1.1f%%', shadow=True)
ax2.axis('equal')
# Out:
# (-1.1167617712064344,
#  1.1007981795812587,
#  -1.1040183564586263,
#  1.1112614252884583)

# %%
conda update -n base -c defaults conda
# Out:
# ...
# Solving environment: ...working...
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==2019.07=py37_0
#   - defaults/win-64::numba==0.44.1=py37hf9181ef_0
#
# ...
#   - defaults::jupyter_console-5.2.0-py37_1, defaults::prompt_toolkit-3.0.2-py_0
#   - defaults::jupyter_console-6.0.0-py37_0, defaults::prompt_toolkit-2.0.9-py37_0done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Zafar\Anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2019.03  |           py37_0           6 KB
#     anaconda-custom            |           py37_1           3 KB
#     anaconda-project-0.8.4     |             py_0         215 KB
#     argh-0.26.2                |           py37_0          36 KB
# ...

# %%
conda install -c conda-forge category_encoders
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Machine Learning Libraries

# %%
# import ml libraries
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import linear_model, datasets
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import accuracy_score
from sklearn.svm import LinearSVC, SVC
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import Normalizer
from sklearn.metrics import f1_score
import category_encoders as ce
import os,sys
from scipy import stats

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# #### feature engineering

# %%
numeric_features = df1.select_dtypes(include=['int64', 'float64']).columns
categorical_features = df1.select_dtypes(include=['object']).drop(['income'], axis=1).columns
X = df1.drop('income', axis=1)
y = df1['income']

# %% [markdown]
# #### Categorical variable endcoder

# %% [markdown]
# le = preprocessing.LabelEncoder()
# label_encoder = le.fit(y)
# y = label_encoder.transform(y)

# %% [markdown]
# #### Test train split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# #### encoder evaluation and radom forest

# %%
encoder_list = [ce.backward_difference.BackwardDifferenceEncoder, 
                ce.basen.BaseNEncoder,
                ce.binary.BinaryEncoder,
                ce.cat_boost.CatBoostEncoder,
                ##ce.hashing.HashingEncoder,
                ##ce.helmert.HelmertEncoder,
                ce.james_stein.JamesSteinEncoder,
                ce.one_hot.OneHotEncoder,
                ce.leave_one_out.LeaveOneOutEncoder,
                ce.m_estimate.MEstimateEncoder,
                ce.ordinal.OrdinalEncoder,
                ce.polynomial.PolynomialEncoder,
                ce.sum_coding.SumEncoder,
                ce.target_encoder.TargetEncoder,
                ce.woe.WOEEncoder
                ]
for encoder in encoder_list:
    
    numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])
    categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('woe', encoder())])
    
    preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])
    
    pipe = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', RandomForestClassifier(n_estimators=500))])
    
    model = pipe.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    print(encoder)
    print(f1_score(y_test, y_pred, average='macro'))
# Out:
# <class 'category_encoders.backward_difference.BackwardDifferenceEncoder'>
# 0.7832643160580044
# <class 'category_encoders.basen.BaseNEncoder'>
# 0.7896005593630979
# <class 'category_encoders.binary.BinaryEncoder'>
# 0.7913061739497712
# <class 'category_encoders.cat_boost.CatBoostEncoder'>
# 0.7875700154737564
# <class 'category_encoders.james_stein.JamesSteinEncoder'>
# 0.7907860414392821
# <class 'category_encoders.one_hot.OneHotEncoder'>
# 0.7881569481569481
# <class 'category_encoders.leave_one_out.LeaveOneOutEncoder'>
# 0.43177455941371484
# C:\Users\Zafar\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# <class 'category_encoders.m_estimate.MEstimateEncoder'>
# 0.7912748288967155
# <class 'category_encoders.ordinal.OrdinalEncoder'>
# 0.7947219468255928
# ...

# %%
print(f1_score(y_test, y_pred, average='macro'))
# Out:
# 0.7970448825118039

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_pred = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.8645785352372178

# %% [markdown]
# #### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[4694,  245],
#        [ 637,  937]], dtype=int64)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(20,20))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(159.0, 0.5, 'Truth')
